# %%
import pandas as pd
import numpy as np

# %%
df1=pd.read_csv(r'C:\Users\abc\Data Science and ML\CampusX\Project\self\flats1.csv')
df2=pd.read_csv(r'C:\Users\abc\Data Science and ML\CampusX\Project\self\house1.csv')

# %%
df=pd.concat([df1,df2],ignore_index=True)

# %%
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)

# %%
df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
df.sample(2)
# Out:
#                                 property_name property_type  \
# 2988              3 BHK Flat in Dharam Colony          flat
# 3035  5 Bedroom House for sale in DLF Phase 2         house
#
#                  society          sector  price_in_lacs  price_per_sqft_inrs  \
# 2988  krishna appartment   dharam colony           35.0               3500.0
# 3035         independent              na          900.0              33333.0
#
#                        area                          areaWithType  bedRoom  \
# 2988                 1000.0  Super Built up area 1000(92.9 sq.m.)        3
# 3035  (251 sq.m.) Plot Area           Plot area 300(250.84 sq.m.)        5
#
#       bathroom balcony                                 additionalRoom  \
# 2988         3       1                                            NaN
# 3035         5      3   pooja room,study room,servant room,store room
#
#                               address  floorNum facing agePossession  \
# 2988  Dharam Colony, Gurgaon, Haryana       2.0    NaN  10+ Year Old
# 3035    DLF Phase 2, Gurgaon, Haryana       3.0  North  10+ Year Old
#
#                                         nearbyLocations  \
# 2988  ['Palam triangle', 'Palam Vihar Vyapar kendra'...
# 3035  ['Vodafone belvedere towers metro station', 'D...
#
#                                             description  \
# 2988  Residential apartment for sell.Located on 2nd ...
# 3035  300 sqyards liveable kothi available for sale ...
#
#                                          furnishDetails  \
# 2988  ['3 Wardrobe', '3 Fan', '3 Light', 'No AC', 'N...
# 3035                                                NaN
#
#                                                features  \
# 2988                                                NaN
# 3035  ['Feng Shui / Vaastu Compliant', 'Maintenance ...
#
#                                                  rating
# 2988  ['Safety4 out of 5', 'Lifestyle4 out of 5', 'E...
# 3035  ['Environment5 out of 5', 'Lifestyle5 out of 5...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3941 entries, 0 to 3940
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   property_name        3941 non-null   object
#  1   property_type        3941 non-null   object
#  2   society              3940 non-null   object
#  3   sector               3941 non-null   object
#  4   price_in_lacs        3941 non-null   float64
#  5   price_per_sqft_inrs  3941 non-null   float64
#  6   area                 3941 non-null   object
#  7   areaWithType         3941 non-null   object
#  8   bedRoom              3941 non-null   int64
#  9   bathroom             3941 non-null   int64
#  10  balcony              3941 non-null   object
#  11  additionalRoom       2637 non-null   object
#  12  address              3930 non-null   object
#  13  floorNum             3920 non-null   float64
#  14  facing               2770 non-null   object
#  15  agePossession        3940 non-null   object
#  16  nearbyLocations      3735 non-null   object
#  17  description          3941 non-null   object
#  18  furnishDetails       2915 non-null   object
#  19  features             3236 non-null   object
#  20  rating               3493 non-null   object
# dtypes: float64(3), int64(2), object(16)
# memory usage: 646.7+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# property_name             0
# property_type             0
# society                   1
# sector                    0
# price_in_lacs             0
# price_per_sqft_inrs       0
# area                      0
# areaWithType              0
# bedRoom                   0
# bathroom                  0
# balcony                   0
# additionalRoom         1304
# address                  11
# floorNum                 21
# facing                 1171
# agePossession             1
# nearbyLocations         206
# description               0
# furnishDetails         1026
# features                705
# rating                  448
# dtype: int64

# %%
df.shape
# Out:
# (3941, 21)

# %% [markdown]
# # Working for sector

# %%
df.drop(columns=['sector'],inplace=True)

# %%
df.insert(3,'sector',df['property_name'].str.strip().str.split('in').str.get(1).str.strip().str.lower().str.replace('gurgaon',''))

# %%
df.sample()
# Out:
#                         property_name property_type                society  \
# 1380  3 BHK Flat in Sector 48 Gurgaon          flat  parsvnath green ville
#
#           sector  price_in_lacs  price_per_sqft_inrs     area  \
# 1380  sector 48           150.0               8787.0  1707.07
#
#                                            areaWithType  bedRoom  bathroom  \
# 1380  Super Built up area 1707(158.59 sq.m.)Built Up...        3         3
#
#      balcony additionalRoom                                   address  \
# 1380       3            NaN  901, Sector 48 Gurgaon, Gurgaon, Haryana
#
#       floorNum facing agePossession  \
# 1380       1.0  North  10+ Year Old
#
#                                         nearbyLocations  \
# 1380  ['Sri Radhe Krishna Temple', 'Icici bank ATM',...
#
#                                             description  \
# 1380  Parsvnath green ville is one of the most popul...
#
#                                          furnishDetails  \
# 1380  ['1 Water Purifier', '7 Fan', '1 Exhaust Fan',...
#
#                                                features  \
# 1380  ['Security / Fire Alarm', 'Feng Shui / Vaastu ...
#
#                                                  rating
# 1380  ['Green Area4 out of 5', 'Construction4 out of...

# %%
#df['sector'].value_counts()

# %%
df['sector'] = df['sector'].str.replace('dharam colony','sector 12')
df['sector'] = df['sector'].str.replace('krishna colony','sector 7')
df['sector'] = df['sector'].str.replace('suncity','sector 54')
df['sector'] = df['sector'].str.replace('prem nagar','sector 13')
df['sector'] = df['sector'].str.replace('mg road','sector 28')
df['sector'] = df['sector'].str.replace('gandhi nagar','sector 28')
df['sector'] = df['sector'].str.replace('laxmi garden','sector 11')
df['sector'] = df['sector'].str.replace('shakti nagar','sector 11')
df['sector'] = df['sector'].str.replace('baldev nagar','sector 7')
df['sector'] = df['sector'].str.replace('shivpuri','sector 7')
df['sector'] = df['sector'].str.replace('garhi harsaru','sector 17')
df['sector'] = df['sector'].str.replace('imt manesar','manesar')
df['sector'] = df['sector'].str.replace('adarsh nagar','sector 12')
df['sector'] = df['sector'].str.replace('shivaji nagar','sector 11')
df['sector'] = df['sector'].str.replace('bhim nagar','sector 6')
df['sector'] = df['sector'].str.replace('madanpuri','sector 7')
df['sector'] = df['sector'].str.replace('saraswati vihar','sector 28')
df['sector'] = df['sector'].str.replace('arjun nagar','sector 8')
df['sector'] = df['sector'].str.replace('ravi nagar','sector 9')
df['sector'] = df['sector'].str.replace('vishnu garden','sector 105')
df['sector'] = df['sector'].str.replace('bhondsi','sector 11')
df['sector'] = df['sector'].str.replace('surya vihar','sector 21')
df['sector'] = df['sector'].str.replace('devilal colony','sector 9')
df['sector'] = df['sector'].str.replace('valley view estate','gwal pahari')
df['sector'] = df['sector'].str.replace('mehrauli  road','sector 14')
df['sector'] = df['sector'].str.replace('jyoti park','sector 7')
df['sector'] = df['sector'].str.replace('ansal plaza','sector 23')
df['sector'] = df['sector'].str.replace('dayanand colony','sector 6')
df['sector'] = df['sector'].str.replace('sushant lok phase 2','sector 55')
df['sector'] = df['sector'].str.replace('chakkarpur','sector 28')
df['sector'] = df['sector'].str.replace('greenwood city','sector 45')
df['sector'] = df['sector'].str.replace('subhash nagar','sector 12')
df['sector'] = df['sector'].str.replace('sohna road road','sohna road')
df['sector'] = df['sector'].str.replace('malibu town','sector 47')
df['sector'] = df['sector'].str.replace('surat nagar 1','sector 104')
df['sector'] = df['sector'].str.replace('new colony','sector 7')
df['sector'] = df['sector'].str.replace('mianwali colony','sector 12')
df['sector'] = df['sector'].str.replace('jacobpura','sector 12')
df['sector'] = df['sector'].str.replace('rajiv nagar','sector 13')
df['sector'] = df['sector'].str.replace('ashok vihar','sector 3')
df['sector'] = df['sector'].str.replace('dlf phase 1','sector 26')
df['sector'] = df['sector'].str.replace('nirvana country','sector 50')
df['sector'] = df['sector'].str.replace('palam vihar','sector 2')
df['sector'] = df['sector'].str.replace('dlf phase 2','sector 25')
df['sector'] = df['sector'].str.replace('sushant lok phase 1','sector 43')
df['sector'] = df['sector'].str.replace('laxman vihar','sector 4')
df['sector'] = df['sector'].str.replace('dlf phase 4','sector 28')
df['sector'] = df['sector'].str.replace('dlf phase 3','sector 24')
df['sector'] = df['sector'].str.replace('sushant lok phase 3','sector 57')
df['sector'] = df['sector'].str.replace('dlf phase 5','sector 43')
df['sector'] = df['sector'].str.replace('rajendra park','sector 105')
df['sector'] = df['sector'].str.replace('uppals southend','sector 49')
df['sector'] = df['sector'].str.replace('sohna','sohna road')
df['sector'] = df['sector'].str.replace('ashok vihar phase 3 extension','sector 5')
df['sector'] = df['sector'].str.replace('south city 1','sector 41')
df['sector'] = df['sector'].str.replace('ashok vihar phase 2','sector 5')
df['sector'] = df['sector'].str.replace('sector 95a','sector 95')
df['sector'] = df['sector'].str.replace('sector 23a','sector 23')
df['sector'] = df['sector'].str.replace('sector 12a','sector 12')
df['sector'] = df['sector'].str.replace('sector 3a','sector 3')
df['sector'] = df['sector'].str.replace('sector 110 a','sector 110')
df['sector'] = df['sector'].str.replace('patel nagar','sector 15')
df['sector'] = df['sector'].str.replace('a block sector 43','sector 43')
df['sector'] = df['sector'].str.replace('maruti kunj','sector 12')
df['sector'] = df['sector'].str.replace('b block sector 43','sector 43')
df['sector'] = df['sector'].str.replace('sector-33 sohna road','sector 33')
df['sector'] = df['sector'].str.replace('sector 1 manesar','manesar')
df['sector'] = df['sector'].str.replace('sector 4 phase 2','sector 4')
df['sector'] = df['sector'].str.replace('sector 1a manesar','manesar')
df['sector'] = df['sector'].str.replace('c block sector 43','sector 43')
df['sector'] = df['sector'].str.replace('sector 89 a','sector 89')
df['sector'] = df['sector'].str.replace('sector 2 extension','sector 2')
df['sector'] = df['sector'].str.replace('sector 36 sohna road','sector 36')

# %%
a=df['sector'].value_counts()[df['sector'].value_counts().values>=3]
df=df[df['sector'].isin(a.index)]

# %%
df.sample(2)
# Out:
#                                        property_name property_type  \
# 2695                3 BHK Flat in Sector 37D Gurgaon          flat
# 3680  5 Bedroom House for sale in Sector 109 Gurgaon         house
#
#                                   society       sector  price_in_lacs  \
# 2695                signature global city  sector 37d           110.0
# 3680  international city by sobha phase 1  sector 109           615.0
#
#       price_per_sqft_inrs                   area  \
# 2695               8800.0                 1250.0
# 3680              27333.0  (226 sq.m.) Plot Area
#
#                                            areaWithType  bedRoom  bathroom  \
# 2695                   Carpet area: 1250 (116.13 sq.m.)        3         3
# 3680  Plot area 270(225.75 sq.m.)Built Up area: 270 ...        5         5
#
#      balcony                      additionalRoom  \
# 2695       3                                 NaN
# 3680     3+   servant room,pooja room,store room
#
#                                           address  floorNum facing  \
# 2695    Z16, Sector 37D Gurgaon, Gurgaon, Haryana       1.0    NaN
# 3680  Block, Sector 109 Gurgaon, Gurgaon, Haryana       3.0   West
#
#         agePossession                                    nearbyLocations  \
# 2695         Dec 2023  ['Sapphire 83 Mall Sector 83', 'Dwarka Express...
# 3680  1 to 5 Year Old  ['Dwarka sector 21 metro station', 'Pacific D2...
#
#                                             description  \
# 2695  U can visit at site which is under constructio...
# 3680  An exclusive villa township\nPhase 1 is spread...
#
#                                          furnishDetails  \
# 2695                                                NaN
# 3680  ['7 Wardrobe', '7 Fan', '6 Geyser', '1 Stove',...
#
#                                                features  \
# 2695  ['Power Back-up', 'Lift(s)', 'Swimming Pool', ...
# 3680  ['Security / Fire Alarm', 'Feng Shui / Vaastu ...
#
#                                                  rating
# 2695  ['Environment4 out of 5', 'Safety4 out of 5', ...
# 3680  ['Environment5 out of 5', 'Lifestyle4 out of 5...

# %% [markdown]
# # areaWithType Column

# %%
temp=df[['area','areaWithType']]
temp.sample(10)
# Out:
#                            area  \
# 3522  (186 sq.m.) Built-up Area
# 1193                    2660.28
# 2094                    1967.15
# 641                      2450.2
# 2829                    1338.24
# 387                     2044.73
# 1364                    4848.03
# 2135                    3149.99
# 3718      (125 sq.m.) Plot Area
# 1473                    3192.17
#
#                                            areaWithType
# 3522  Built Up area: 2000 (185.81 sq.m.)Carpet area:...
# 1193             Super Built up area 2660(247.12 sq.m.)
# 2094                   Carpet area: 1967 (182.74 sq.m.)
# 641              Super Built up area 2450(227.61 sq.m.)
# 2829             Super Built up area 1350(125.42 sq.m.)
# 387              Super Built up area 1689(156.91 sq.m.)
# 1364  Super Built up area 4848(450.39 sq.m.)Built Up...
# 2135                    Carpet area: 350 (292.64 sq.m.)
# 3718                        Plot area 150(125.42 sq.m.)
# 1473  Super Built up area 3192(296.55 sq.m.)Built Up...

# %%
# Carpet area
import re
def carpet_area(area):
    pattern=re.compile(r'.*(Carpet area):\s*(\d+)\s*?.*(\(.*\))?.*')
    matches=re.finditer(pattern,area)
    for match in matches:
        return match.group(2)

# %%
temp['carpet_area']=temp['areaWithType'].apply(carpet_area)
# Out:
# C:\Users\abc\AppData\Local\Temp\ipykernel_1508\809752452.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['carpet_area']=temp['areaWithType'].apply(carpet_area)

# %%
#pd.set_option('display.max_colwidth',None)
#temp.head(15)

# %%
# Super Built-up area
import re
def super_builtup(area):
    pattern=re.compile(r'.*(Super Built up area):*\s*(\d+)\s*?.*(\(.*\))?.*')
    matches=re.finditer(pattern,area)
    for match in matches:
        return match.group(2)

# %%
temp['super_builtup']=temp['areaWithType'].apply(super_builtup)
# Out:
# C:\Users\abc\AppData\Local\Temp\ipykernel_1508\3106186512.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['super_builtup']=temp['areaWithType'].apply(super_builtup)

# %%
temp.sample(5)
# Out:
#          area                                       areaWithType carpet_area  \
# 254    2500.0  Super Built up area 2350(218.32 sq.m.)Built Up...        2000
# 420   2095.39             Super Built up area 2095(194.63 sq.m.)        None
# 1248  1578.17  Super Built up area 1578(146.6 sq.m.)Carpet ar...        1310
# 1057  1741.19                   Carpet area: 1741 (161.74 sq.m.)        1741
# 1911  3020.13                   Carpet area: 3020 (280.57 sq.m.)        3020
#
#      super_builtup
# 254           2350
# 420           2095
# 1248          1578
# 1057          None
# 1911          None

# %%
# Built-up area
import re
def builtup(area):
    pattern=re.compile(r'.*(Built Up area):*\s*(\d+)\s*?.*(\(.*\)).*')
    matches=re.finditer(pattern,area)
    for match in matches:
        return match.group(2)

# %%
temp['builtup']=temp['areaWithType'].apply(builtup)
# Out:
# C:\Users\abc\AppData\Local\Temp\ipykernel_1508\883684273.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['builtup']=temp['areaWithType'].apply(builtup)

# %%
temp['area'][temp['area']==1822.0]
# Out:
# Series([], Name: area, dtype: object)

# %%
temp.duplicated().sum()
# Out:
# 655

# %%
temp.sample(10)
# Out:
#                            area  \
# 3299       (50 sq.m.) Plot Area
# 3218    (134 sq.m.) Carpet Area
# 2950                    1294.92
# 3716      (669 sq.m.) Plot Area
# 3684      (418 sq.m.) Plot Area
# 3205  (325 sq.m.) Built-up Area
# 3146      (166 sq.m.) Plot Area
# 1380                    1707.07
# 2377                     560.04
# 3434       (51 sq.m.) Plot Area
#
#                                            areaWithType carpet_area  \
# 3299                                       Plot area 50        None
# 3218                    Carpet area: 160 (133.78 sq.m.)         160
# 2950             Super Built up area 1295(120.31 sq.m.)        None
# 3716                         Plot area 800(668.9 sq.m.)        None
# 3684                        Plot area 500(418.06 sq.m.)        None
# 3205  Built Up area: 3500 (325.16 sq.m.)Carpet area:...        2500
# 3146                       Plot area 1782(165.55 sq.m.)        None
# 1380  Super Built up area 1707(158.59 sq.m.)Built Up...        1400
# 2377                     Carpet area: 560 (52.03 sq.m.)         560
# 3434                          Plot area 550(51.1 sq.m.)        None
#
#      super_builtup builtup
# 3299          None    None
# 3218          None    None
# 2950          1295    None
# 3716          None    None
# 3684          None    None
# 3205          None    3500
# 3146          None    None
# 1380          1707    1600
# 2377          None    None
# 3434          None    None

# %%
def plot_area(area):
    pattern=re.compile(r'(Plot area)\s*?(\d+)(\(\d+.*\))?.*')
    matches=re.finditer(pattern,area)
    for match in matches:
        return match.group(2)

# %%
text='Plot area 290(242.48 sq.m.)'
pattern=re.compile(r'(Plot area)\s*?(\d+)(\(\d+.*\))?.*')
matches=re.finditer(pattern,text)
for match in matches:
    print(match.group(2))
# Out:
# 290

# %%
ind=temp[(temp['carpet_area'].isnull())&(temp['super_builtup'].isnull())&(temp['builtup'].isnull())]['areaWithType'].index

# %%
temp[(temp['carpet_area'].isnull())&(temp['super_builtup'].isnull())&(temp['builtup'].isnull())]['areaWithType'].apply(plot_area).values
# Out:
# array(['290', '61', '129', '62', '128', '360', '500', '316', '215', '150',
#        '360', '163', '502', '300', '400', '100', '240', '320', '292',
#        '350', '360', '360', '215', '300', '563', '290', '263', '360',
#        '251', '300', '351', '160', '192', '300', '300', '300', '200',
#        '300', '300', '305', '300', '200', '290', '215', '173', '360',
#        '4500', '163', '288', '4000', '161', '3400', '3400', '900', '263',
#        '342', '270', '600', '250', '550', '975', '360', '87', '600',
#        '263', '304', '355', '360', '120', '292', '160', '250', '160',
#        '4000', '500', '600', '400', '600', '270', '161', '270', '246',
#        '6000', '200', '80', '1350', '1500', '67', '70', '61', '76', '215',
#        '270', '167', '200', '173', '107', '215', '500', '500', '600',
#        '550', '684', '60', '1070', '14', '275', '167', '100', '600',
#        '450', '109', '1800', '1782', '400', '100', '1700', '150', '1200',
#        '200', '2250', '3653', '270', '250', '500', '303', '1152', '360',
#        '150', '360', '1782', '515', '900', '240', '159', '33', '108',
#        '200', '1800', '160', '5000', '390', '67', '40', '1900', '200',
#        '450', '3500', '65', '62', '450', '612', None, '2500', '1440',
#        '270', '138', '1575', '130', '200', '100', '50', '360', '40',
#        '348', '294', '62', '550', '60', '57', '920', '115', '270', '40',
#        '1337', '100', '785', '640', '1125', '220', '62', '350', '900',
#        '135', '900', '200', '1460', '40', '130', '50', '540', '2', '67',
#        '146', '117', '402', '55', '1800', '900', '1185', '200', '432',
#        '624', '300', '600', '4000', '360', '150', '1300', '60', '450',
#        '135', '4200', '200', '75', '900', '163', '800', '1069', '208',
#        '117', '900', '550', '192', '900', '892', '891', '450', '900',
#        '316', '166', '300', '138', '713', '864', '1000', '1150', '50',
#        '150', '945', '1350', '500', '600', '477', '50', '60', '109',
#        '120', '900', '502', '120', None, '480', '1160', '585', '250',
#        '342', '60', '2700', '900', '900', '1000', '380', '120', '225',
#        '111', '1065', '255', '600', '130', '1125', '420', '150', '502',
#        '316', '502', '360', '300', '502', '173', '502', '360', '400',
#        '100', '100', '235', '60', '4500', '205', '200', '692', '2160',
#        '360', '60', '300', '215', '204', '1000', '400', '250', '2500',
#        '350', '6300', '360', '168', '502', '300', '2000', '7000', '900',
#        '60', '358', '360', '250', '240', '400', '1254', '338', '382',
#        '300', '275', '150', '200', '300', '358', '402', '263', '215',
#        '400', '265', '150', '173', '502', '502', '502', '204', '600',
#        '360', '1549', '161', '300', '505', '240', '5850', '360', '360',
#        '204', '205', '173', '66', '200', '502', '502', '200', '316',
#        '400', '360', '270', '359', '275', '270', '290', '360', '400',
#        '500', '360', '500', '360', '270', '173', '502', '300', '3450',
#        '316', '320', '320', '360', '64', '500', '204', '1570', '1095',
#        '270', '500', '360', '300', '360', '300', '800', '150', '192',
#        '418', '402', '502', '419', '360', '2400', '692', '3194', '215',
#        '400', '692', '418', '215', '161', '270', '300', '250', '2425',
#        '240', '300', '610', '250', '360', '185', '300', '360', '360',
#        '360', '299', '360', '361', '250', '400', '200', '5480', '192',
#        '161', '300', '180', '270', '360', '400', '1000', '200', '280',
#        '316', '300', '502', '500', '160', '180', '500', '1000', '173',
#        '1450', '160', '418', '500', '300', '754', '521', '360', '342',
#        '7000', '270', '270', '240', '290', '550', '267', '546', '260',
#        '260', '275', '692', '520', '192', '300', '3200', '250', '263',
#        '160', '215', '226', '200', '200', '316', '260', '180', '160',
#        '180', '204', '1000', '1700', '360', '502', '344', '189', '170',
#        '150', '215', '316', '375', '232', '240', '502', '288', '232',
#        '4000', '360', '300', '270', '360', '240', '360', '384', '240',
#        '692', '360', '5400', '530', '150', '126', '520', '316', '502',
#        '150', '270', '500', '161', '100', '172', '204', '263', '101',
#        '161', '263', '161', '161', '172', '200', '150', '150', '109'],
#       dtype=object)

# %%
ind.shape
# Out:
# (535,)

# %%
temp.loc[ind,'builtup']=temp[(temp['carpet_area'].isnull())&(temp['super_builtup'].isnull())&(temp['builtup'].isnull())]['areaWithType'].apply(plot_area).values

# %%
temp.sample(1)
# Out:
#           area                        areaWithType carpet_area super_builtup  \
# 1430  49122.81  Carpet area: 48811 (4534.69 sq.m.)       48811          None
#
#      builtup
# 1430    None

# %%
df.insert(8,'super_builtup',temp['super_builtup'])

# %%
df.insert(9,'builtup',temp['builtup'])
df.insert(10,'carpet_area',temp['carpet_area'])

# %%
df.sample(2)
# Out:
#                                         property_name property_type  \
# 3459    5 Bedroom House for sale in Sector 72 Gurgaon         house
# 3765  4 Bedroom House for sale in Sushant Lok Phase 3         house
#
#           society      sector  price_in_lacs  price_per_sqft_inrs  \
# 3459  spaze privy  sector 72           309.0               6981.0
# 3765  independent   sector 57          349.0              20197.0
#
#                            area  \
# 3459  (339 sq.m.) Built-up Area
# 3765      (161 sq.m.) Plot Area
#
#                                            areaWithType super_builtup builtup  \
# 3459  Built Up area: 3653 (339.37 sq.m.)Carpet area:...          None    3653
# 3765                        Plot area 192(160.54 sq.m.)          None     192
#
#      carpet_area  bedRoom  bathroom balcony  \
# 3459        2922        5         5     3+
# 3765        None        4         4      2
#
#                           additionalRoom  \
# 3459                        servant room
# 3765  study room,pooja room,servant room
#
#                                                 address  floorNum      facing  \
# 3459  Flat No-141, Tower- H, Spaze Privy Sector -72,...      14.0        East
# 3765        E 73, Sushant Lok Phase 3, Gurgaon, Haryana       3.0  South-East
#
#          agePossession                                    nearbyLocations  \
# 3459   1 to 5 Year Old                                                NaN
# 3765  5 to 10 Year Old  ['Radhakrishna Shani Mandir', 'Sanatan Dharm M...
#
#                                             description  \
# 3459  5bhk penthouse for new property in spaze privy...
# 3765  On the lookout for a spacious house in gurgaon...
#
#                                          furnishDetails  \
# 3459  ['5 Wardrobe', '1 Water Purifier', '9 Fan', '1...
# 3765  ['6 Wardrobe', '10 Fan', '1 Exhaust Fan', '6 G...
#
#                                                features  \
# 3459  ['Swimming Pool', 'Separate entry for servant ...
# 3765  ['Feng Shui / Vaastu Compliant', 'Private Gard...
#
#                                                  rating
# 3459  ['Environment4.5 out of 5', 'Lifestyle4.5 out ...
# 3765  ['Environment4 out of 5', 'Safety4 out of 5', ...

# %% [markdown]
# # additionalRoom

# %%
def servant_check(room):
    if pd.isna(room):
        return 0
    elif 'servant room' in room:
        return 1   
    else:
        return 0

# %%
df['servant_room']=df['additionalRoom'].str.strip().str.lower().apply(servant_check)

# %%
def study_room(room):
    if pd.isna(room):
        return 0
    elif 'study room' in room:
        return 1   
    else:
        return 0

# %%
df['study room']=df['additionalRoom'].str.lower().str.strip().apply(study_room)

# %%
def pooja_room(room):
    if pd.isna(room):
        return 0
    elif 'pooja room' in room:
        return 1   
    else:
        return 0

# %%
df["pooja room"]=df['additionalRoom'].str.lower().str.strip().apply(pooja_room)

# %%
def store_room(room):
    if pd.isna(room):
        return 0
    elif 'store room' in room:
        return 1   
    else:
        return 0

# %%
df['store_room']=df['additionalRoom'].str.lower().str.strip().apply(store_room)

# %%
def others(room):
    if pd.isna(room):
        return 0
    elif 'others' in room:
        return 1   
    else:
        return 0

# %%
df['others']=df['additionalRoom'].str.lower().str.strip().apply(others)

# %%
df.sample(2)
# Out:
#                         property_name property_type  \
# 1256  2 BHK Flat in Sector 85 Gurgaon          flat
# 1632  4 BHK Flat in Sector 50 Gurgaon          flat
#
#                              society      sector  price_in_lacs  \
# 1256                     ss the leaf  sector 85           114.0
# 1632  the penthouses at the hibiscus  sector 50           850.0
#
#       price_per_sqft_inrs     area                            areaWithType  \
# 1256               6433.0  1772.11  Super Built up area 1772(164.62 sq.m.)
# 1632               8500.0  10000.0       Carpet area: 10000 (929.03 sq.m.)
#
#      super_builtup builtup carpet_area  bedRoom  bathroom balcony  \
# 1256          1772    None        None        2         2       3
# 1632          None    None       10000        4         4       3
#
#      additionalRoom                              address  floorNum  \
# 1256            NaN  Sector 85 Gurgaon, Gurgaon, Haryana      16.0
# 1632   Servant Room  Sector 50 Gurgaon, Gurgaon, Haryana       9.0
#
#           facing     agePossession  \
# 1256       South   1 to 5 Year Old
# 1632  South-East  5 to 10 Year Old
#
#                                         nearbyLocations  \
# 1256  ['Sapphire 83 Mall', 'Dwarka Expressway', 'Cen...
# 1632  ['Sector 55-56 Metro Station', 'Good Earth Cit...
#
#                                             description  \
# 1256  Situated in sector 85 gurgaon, ss the leaf is ...
# 1632  4 bedroom 10000 sq.Ft. Middle floor penthouse ...
#
#                                          furnishDetails  \
# 1256                                                NaN
# 1632  ['4 Fan', '8 Light', 'No AC', 'No Bed', 'No Ch...
#
#                                                features  \
# 1256  ['Security / Fire Alarm', 'Intercom Facility',...
# 1632  ['Power Back-up', 'Feng Shui / Vaastu Complian...
#
#                                                  rating  servant_room  \
# 1256  ['Green Area4.5 out of 5', 'Construction4.5 ou...             0
# 1632  ['Environment5 out of 5', 'Lifestyle5 out of 5...             1
#
#       study room  pooja room  store_room  others
# 1256           0           0           0       0
# 1632           0           0           0       0

# %% [markdown]
# # agePossession

# %%
df['agePossession'].value_counts().sample(5)
# Out:
# agePossession
# Dec 2024    16
# By 2024     17
# Nov 2023     5
# Jan 2025     3
# Dec 2025     7
# Name: count, dtype: int64

# %%
def categorize_age_possession(value):
    if pd.isna(value):
        return "Undefined"
    if "0 to 1 Year Old" in value or "Within 6 months" in value or "Within 3 months" in value:
        return "New Property"
    if "1 to 5 Year Old" in value:
        return "Relatively New"
    if "5 to 10 Year Old" in value:
        return "Moderately Old"
    if "10+ Year Old" in value:
        return "Old Property"
    if "Under Construction" in value or "By" in value:
        return "Under Construction"
    try:
        # For entries like 'May 2024'
        int(value.split(" ")[-1])
        return "Under Construction"
    except:
        return "Undefined"

# %%
df['agePossession'] = df['agePossession'].apply(categorize_age_possession)

# %%
df['agePossession'].value_counts()
# Out:
# agePossession
# Relatively New        1669
# New Property           623
# Moderately Old         569
# Undefined              328
# Old Property           307
# Under Construction     282
# Name: count, dtype: int64

# %% [markdown]
# # furnishDetails

# %%
pd.reset_option('all')
# Out:
# C:\Users\abc\AppData\Local\Temp\ipykernel_1508\2786130087.py:1: FutureWarning: data_manager option is deprecated and will be removed in a future version. Only the BlockManager will be available.
#   pd.reset_option('all')
# C:\Users\abc\AppData\Local\Temp\ipykernel_1508\2786130087.py:1: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   pd.reset_option('all')

# %%
furnish=df['furnishDetails'].reset_index()

# %%
pd.set_option('display.max_colwidth',None)

# %%
def light(row):
    if pd.isna(row):
        return 0
    else:
        pattern=re.compile(r',?\'(\d+)\s*(light)\',?|(no)\s*(light)\',?')
        matches=re.finditer(pattern,row)
        for match in matches:
            return match.group(1)
    return 0

# %%
temp=furnish['furnishDetails'].str.lower().apply(light)

# %%
temp[temp.isnull()]=0

# %%
furnish['light']=temp

# %%
pd.set_option('display.max_colwidth',None)

# %%
furnish.head()
# Out:
#    index  \
# 0      0
# 1      1
# 2      2
# 3      3
# 4      4
#
#                                                                                                                                                                                                                                                        furnishDetails  \
# 0  ['3 Fan', '4 Light', '1 Wardrobe', 'No AC', 'No Bed', 'No Chimney', 'No Curtains', 'No Dining Table', 'No Exhaust Fan', 'No Geyser', 'No Modular Kitchen', 'No Microwave', 'No Fridge', 'No Sofa', 'No Stove', 'No TV', 'No Washing Machine', 'No Water Purifier']
# 1       ['3 Wardrobe', '4 Fan', '1 Exhaust Fan', '1 Geyser', '3 Light', '1 Curtains', '1 Chimney', '1 Modular Kitchen', 'No AC', 'No Bed', 'No Dining Table', 'No Microwave', 'No Fridge', 'No Sofa', 'No Stove', 'No TV', 'No Washing Machine', 'No Water Purifier']
# 2                                                                                                                                                                                                                                                                 NaN
# 3                                                                                                                                                                                                                                                                 NaN
# 4                                                                                                                                                                                                                                                                  []
#
#   light
# 0     4
# 1     3
# 2     0
# 3     0
# 4     0

# %%
def fan(row):
    if pd.isna(row):
        return 0
    else:
        pattern=re.compile(r',?\'(\d+)\s*(fan)\',?|(no)\s*(fan)\',?')
        matches=re.finditer(pattern,row)
        for match in matches:
            return match.group(1)
    return 0

# %%
temp=furnish['furnishDetails'].str.lower().apply(fan)
temp[temp.isnull()]=0
furnish['fan']=temp

# %%
# Extract all unique furnishings from the furnishDetails column
all_furnishings = []
for detail in furnish['furnishDetails'].dropna():
    furnishings = detail.replace('[', '').replace(']', '').replace("'", "").split(', ')
    all_furnishings.extend(furnishings)
unique_furnishings = list(set(all_furnishings))

# %%
unique=[]
for i in unique_furnishings:
    patter=re.compile(r'(\d+)\s*?([a-z]+)')
    match=re.finditer(patter,i.strip().lower())
    for matches in match:
        unique.append((matches.group(2)))

# %%
new_list=list(set(unique))
new_list
# Out:
# ['chimney',
#  'washing',
#  'stove',
#  'microwave',
#  'fridge',
#  'modular',
#  'geyser',
#  'tv',
#  'dining',
#  'water',
#  'ac',
#  'curtains',
#  'exhaust',
#  'fan',
#  'sofa',
#  'wardrobe',
#  'bed',
#  'light']

# %%
def ac(row):
    if pd.isna(row):
        return 0
    else:
        pattern=re.compile(r',?\'(\d+)\s*(ac)\',?|(no)\s*(ac)\',?')
        matches=re.finditer(pattern,row)
        for match in matches:
            return match.group(1)
    return 0

# %%
temp=furnish['furnishDetails'].str.lower().apply(ac)
temp[temp.isnull()]=0
furnish['ac']=temp

# %%
def wardrobe(row):
    if pd.isna(row):
        return 0
    else:
        pattern=re.compile(r',?\'(\d+)\s*(wardrobe)\',?|(no)\s*(wardrobe)\',?')
        matches=re.finditer(pattern,row)
        for match in matches:
            return match.group(1)
    return 0

temp=furnish['furnishDetails'].str.lower().apply(wardrobe)
temp[temp.isnull()]=0
furnish['wardrobe']=temp

# %%
def stove(row):
    if pd.isna(row):
        return 0
    else:
        pattern=re.compile(r',?\'(\d+)\s*(stove)\',?|(no)\s*(stove)\',?')
        matches=re.finditer(pattern,row)
        for match in matches:
            return match.group(1)
    return 0

temp=furnish['furnishDetails'].str.lower().apply(stove)
temp[temp.isnull()]=0
furnish['stove']=temp

# %%
def sofa(row):
    if pd.isna(row):
        return 0
    else:
        pattern=re.compile(r',?\'(\d+)\s*(sofa)\',?|(no)\s*(sofa)\',?')
        matches=re.finditer(pattern,row)
        for match in matches:
            return match.group(1)
    return 0

temp=furnish['furnishDetails'].str.lower().apply(sofa)
temp[temp.isnull()]=0
furnish['sofa']=temp

# %%
def exhaust_fan(row):
    if pd.isna(row):
        return 0
    else:
        pattern=re.compile(r',?\'(\d+)\s*(exhaust fan)\',?|(no)\s*(exhaust fan)\',?')
        matches=re.finditer(pattern,row)
        for match in matches:
            return match.group(1)
    return 0

temp=furnish['furnishDetails'].str.lower().apply(exhaust_fan)
temp[temp.isnull()]=0
furnish['exhaust_fan']=temp

# %%
def geyser(row):
    if pd.isna(row):
        return 0
    else:
        pattern=re.compile(r',?\'(\d+)\s*(geyser)\',?|(no)\s*(geyser)\',?')
        matches=re.finditer(pattern,row)
        for match in matches:
            return match.group(1)
    return 0

temp=furnish['furnishDetails'].str.lower().apply(geyser)
temp[temp.isnull()]=0
furnish['geyser']=temp

# %%
def dining(row):
    if pd.isna(row):
        return 0
    else:
        pattern=re.compile(r',?\'(\d+)\s*(dining table)\',?|(no)\s*(dining table)\',?')
        matches=re.finditer(pattern,row)
        for match in matches:
            return match.group(1)
    return 0

temp=furnish['furnishDetails'].str.lower().apply(dining)
temp[temp.isnull()]=0
furnish['dining']=temp

# %%
def curtains(row):
    if pd.isna(row):
        return 0
    else:
        pattern=re.compile(r',?\'(\d+)\s*(curtains)\',?|(no)\s*(curtains)\',?')
        matches=re.finditer(pattern,row)
        for match in matches:
            return match.group(1)
    return 0

temp=furnish['furnishDetails'].str.lower().apply(curtains)
temp[temp.isnull()]=0
furnish['curtains']=temp

# %%
def modular(row):
    if pd.isna(row):
        return 0
    else:
        pattern=re.compile(r',?\'(\d+)\s*(modular kitchen)\',?|(no)\s*(modular kitchen)\',?')
        matches=re.finditer(pattern,row)
        for match in matches:
            return match.group(1)
    return 0

temp=furnish['furnishDetails'].str.lower().apply(modular)
temp[temp.isnull()]=0
furnish['modular']=temp

# %%
def chimney(row):
    if pd.isna(row):
        return 0
    else:
        pattern=re.compile(r',?\'(\d+)\s*(chimney)\',?|(no)\s*(chimney)\',?')
        matches=re.finditer(pattern,row)
        for match in matches:
            return match.group(1)
    return 0

temp=furnish['furnishDetails'].str.lower().apply(chimney)
temp[temp.isnull()]=0
furnish['chimney']=temp

# %%
def bed(row):
    if pd.isna(row):
        return 0
    else:
        pattern=re.compile(r',?\'(\d+)\s*(bed)\',?|(no)\s*(bed)\',?')
        matches=re.finditer(pattern,row)
        for match in matches:
            return match.group(1)
    return 0

temp=furnish['furnishDetails'].str.lower().apply(bed)
temp[temp.isnull()]=0
furnish['bed']=temp

# %%
def tv(row):
    if pd.isna(row):
        return 0
    else:
        pattern=re.compile(r',?\'(\d+)\s*(tv)\',?|(no)\s*(tv)\',?')
        matches=re.finditer(pattern,row)
        for match in matches:
            return match.group(1)
    return 0

temp=furnish['furnishDetails'].str.lower().apply(tv)
temp[temp.isnull()]=0
furnish['tv']=temp

# %%
def water_purifier(row):
    if pd.isna(row):
        return 0
    else:
        pattern=re.compile(r',?\'(\d+)\s*(water purifier)\',?|(no)\s*(water purifier)\',?')
        matches=re.finditer(pattern,row)
        for match in matches:
            return match.group(1)
    return 0

temp=furnish['furnishDetails'].str.lower().apply(water_purifier)
temp[temp.isnull()]=0
furnish['water_purifier']=temp

# %%
def microwave(row):
    if pd.isna(row):
        return 0
    else:
        pattern=re.compile(r',?\'(\d+)\s*(microwave)\',?|(no)\s*(microwave)\',?')
        matches=re.finditer(pattern,row)
        for match in matches:
            return match.group(1)
    return 0

temp=furnish['furnishDetails'].str.lower().apply(microwave)
temp[temp.isnull()]=0
furnish['microwave']=temp

# %%
def fridge(row):
    if pd.isna(row):
        return 0
    else:
        pattern=re.compile(r',?\'(\d+)\s*(fridge)\',?|(no)\s*(fridge)\',?')
        matches=re.finditer(pattern,row)
        for match in matches:
            return match.group(1)
    return 0

temp=furnish['furnishDetails'].str.lower().apply(fridge)
temp[temp.isnull()]=0
furnish['fridge']=temp

# %%
def washing_machine(row):
    if pd.isna(row):
        return 0
    else:
        pattern=re.compile(r',?\'(\d+)\s*(washing machine)\',?|(no)\s*(washing machine)\',?')
        matches=re.finditer(pattern,row)
        for match in matches:
            return match.group(1)
    return 0

temp=furnish['furnishDetails'].str.lower().apply(washing_machine)
temp[temp.isnull()]=0
furnish['washing_machine']=temp

# %%
furnish.drop(columns=['index'],inplace=True)

# %%
furnish.sample(3)
# Out:
#                                                                                                                                                                                                                                                            furnishDetails  \
# 2078  ['6 Fan', '8 Light', 'No AC', 'No Bed', 'No Chimney', 'No Curtains', 'No Dining Table', 'No Exhaust Fan', 'No Geyser', 'No Modular Kitchen', 'No Microwave', 'No Fridge', 'No Sofa', 'No Stove', 'No TV', 'No Wardrobe', 'No Washing Machine', 'No Water Purifier']
# 2183     ['1 Wardrobe', '1 Exhaust Fan', '6 Light', '1 Chimney', '1 Modular Kitchen', 'No AC', 'No Bed', 'No Curtains', 'No Dining Table', 'No Fan', 'No Geyser', 'No Microwave', 'No Fridge', 'No Sofa', 'No Stove', 'No TV', 'No Washing Machine', 'No Water Purifier']
# 2421      ['2 Fan', '1 Washing Machine', '6 Light', '1 AC', '1 Chimney', '2 Curtains', 'No Bed', 'No Dining Table', 'No Exhaust Fan', 'No Geyser', 'No Modular Kitchen', 'No Microwave', 'No Fridge', 'No Sofa', 'No Stove', 'No TV', 'No Wardrobe', 'No Water Purifier']
#
#      light fan ac wardrobe stove sofa exhaust_fan geyser dining curtains  \
# 2078     8   6  0        0     0    0           0      0      0        0
# 2183     6   0  0        1     0    0           1      0      0        0
# 2421     6   2  1        0     0    0           0      0      0        2
#
#      modular chimney bed tv water_purifier microwave fridge washing_machine
# 2078       0       0   0  0              0         0      0               0
# 2183       1       1   0  0              0         0      0               0
# 2421       0       1   0  0              0         0      0               1

# %%
pd.reset_option('all')
# Out:
# C:\Users\abc\AppData\Local\Temp\ipykernel_1508\2786130087.py:1: FutureWarning: data_manager option is deprecated and will be removed in a future version. Only the BlockManager will be available.
#   pd.reset_option('all')
# C:\Users\abc\AppData\Local\Temp\ipykernel_1508\2786130087.py:1: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   pd.reset_option('all')

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
sclaed=ss.fit_transform(furnish.iloc[:,1:])

# %%
from sklearn.cluster import KMeans
wcss=[]
for i in range(1,19):
    kmeans=KMeans(n_clusters=i,algorithm='lloyd')
    kmeans.fit(sclaed)
    wcss.append(kmeans.inertia_)
# Out:
# C:\Users\abc\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# found 0 physical cores < 1
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "C:\Users\abc\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py", line 282, in _count_physical_cores
#     raise ValueError(f"found {cpu_count_physical} physical cores < 1")

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(12,8))
sns.lineplot(x=list(range(1,19)),y=wcss,marker='o',linestyle='--')
plt.xlabel('No of Cluster')
plt.ylabel('WCSS')
plt.xticks(range(1,19))
plt.grid(True)
plt.show()

# %%
n_cluster=3
kmeans=KMeans(n_clusters=n_cluster,algorithm='lloyd')
kmeans.fit(sclaed)
# Out:
# KMeans(n_clusters=3)

# %%
furnish['type']=kmeans.predict(sclaed)

# %%
furnish['type'].value_counts()
# Out:
# type
# 0    2483
# 2    1078
# 1     217
# Name: count, dtype: int64

# %%
df.insert(22,'furnish_type',furnish['type'])

# %%
df.sample(1)
# Out:
#                                 property_name property_type      society  \
# 3559  10 Bedroom House for sale in Sohna Road         house  independent
#
#                sector  price_in_lacs  price_per_sqft_inrs  \
# 3559  sohna road road           95.0               8920.0
#
#                       area                 areaWithType super_builtup builtup  \
# 3559  (99 sq.m.) Plot Area  Plot area 1065(98.94 sq.m.)          None    1065
#
#       ...                                        description  \
# 3559  ...  Interested to sell independent house/villa con...
#
#                                          furnishDetails  furnish_type  \
# 3559  ['1 Bed', '1 Wardrobe', '1 Fan', '1 Light', 'N...           0.0
#
#      features rating servant_room  study room pooja room store_room others
# 3559      NaN    NaN            0           0          0          0      0
#
# [1 rows x 30 columns]

# %% [markdown]
# # feature

# %%
df['features'].sample(2)
# Out:
# 878    ['Security / Fire Alarm', 'Power Back-up', 'Li...
# 137    ['Lift(s)', 'Intercom Facility', 'Security / F...
# Name: features, dtype: object

# %%
app_df=pd.read_csv(r'C:\Users\abc\Data Science and ML\CampusX\Project\appartments.csv')

# %%
df[['society','features']].sample(2)
# Out:
#            society                                           features
# 454   pioneer park  ['Security / Fire Alarm', 'Feng Shui / Vaastu ...
# 1706  tulip violet  ['Water purifier', 'Security / Fire Alarm', 'P...

# %%
nofeatures_society=df['society'][pd.isnull(df['features'])]

# %%
app_df['PropertyName']=app_df['PropertyName'].str.strip().str.lower()

# %%
app_df[['PropertyName','TopFacilities']].sample(2)
# Out:
#                             PropertyName  \
# 57                     dlf the magnolias
# 145  central park flower valley the room
#
#                                          TopFacilities
# 57   ['Mini Theatre', 'Swimming Pool', 'Football', ...
# 145  ['Swimming Pool', 'Laundry', 'ATM', 'Restauran...

# %%
# for i in df['society'][pd.isnull(df['features'])].values:
#     for j in app_df['PropertyName'].values:
#         if i==j:
#             df['features'][df['society']==i]=app_df['TopFacilities'][app_df['PropertyName']==j]

# %%
# Create a mapping from app_df
mapping = app_df.set_index('PropertyName')['TopFacilities']

# Only update 'features' where it's null and 'society' exists in mapping
mask = df['features'].isnull()
df.loc[mask, 'features'] = df.loc[mask, 'society'].map(mapping)

# %%
# for i in range(len(df['features'][~df['features'].isnull()])):
#     for j in df['features'][~df['features'].isnull()].str.strip().str.replace('[','').str.replace(']','').str.strip().str.split(',')[i]:
#         print(j)

# %%
len(df['features'][~df['features'].isnull()])

# %%
# Get only non-null features
non_null_features = df['features'].dropna()

# Clean and split each feature string
for feature_str in non_null_features:
    # Remove brackets, strip whitespace, then split
    cleaned = feature_str.strip().strip('[]')  # removes leading/trailing spaces and brackets
    items = [item.strip() for item in cleaned.split(',') if item.strip()]  # remove extra spaces
    # for item in items:
    #     print((item))

# %%
new=[]
for i in non_null_features[0].strip().strip('[]').strip().split(','):
    new.append(i.strip(''))

# %%
app_df['PropertyName'] = app_df['PropertyName'].str.lower()

# %%
temp_df = df[df['features'].isnull()]

# %%
x = temp_df.merge(app_df,left_on='society',right_on='PropertyName',how='left')['TopFacilities']

# %%
df.loc[temp_df.index,'features'] = x.values

# %%
from sklearn.preprocessing import MultiLabelBinarizer
import ast

# Convert the string representation of lists in the 'features' column to actual lists
df['features_list'] = df['features'].apply(lambda x: ast.literal_eval(x) if pd.notnull(x) and x.startswith('[') else [])

# Use MultiLabelBinarizer to convert the features list into a binary matrix
mlb = MultiLabelBinarizer()
features_binary_matrix = mlb.fit_transform(df['features_list'])

# Convert the binary matrix into a DataFrame
features_binary_df = pd.DataFrame(features_binary_matrix, columns=mlb.classes_)

# %%
features_binary_df.sample(5)
# Out:
#       24/7 Power Backup  24/7 Water Supply  24x7 Security  ATM  \
# 1512                  0                  0              0    0
# 158                   0                  0              0    0
# 2241                  0                  0              0    0
# 1098                  0                  0              0    0
# 1151                  0                  0              0    0
#
#       Aerobics Centre  Air Hockey  Airy Rooms  Amphitheatre  \
# 1512                0           0           0             0
# 158                 0           0           0             0
# 2241                0           0           0             0
# 1098                0           0           1             0
# 1151                0           0           0             0
#
#       Automated Car Wash  Badminton Court  ...  Visitors Parking  \
# 1512                   0                0  ...                 0
# 158                    0                0  ...                 0
# 2241                   0                0  ...                 0
# 1098                   0                0  ...                 0
# 1151                   0                0  ...                 0
#
#       Volley Ball Court  Waiting Lounge  Waste Disposal  Water Softener Plant  \
# 1512                  0               0               0                     0
# 158                   0               0               0                     0
# 2241                  0               0               0                     0
# 1098                  0               0               1                     0
# 1151                  0               0               1                     0
#
#       Water Storage  Water purifier  Water softening plant  \
# 1512              1               0                      0
# 158               0               0                      0
# 2241              1               0                      0
# 1098              1               1                      1
# 1151              1               0                      1
#
#       Wi-Fi Connectivity  Yoga/Meditation Area
# 1512                   0                     0
# 158                    0                     0
# 2241                   0                     0
# 1098                   0                     0
# 1151                   0                     0
#
# [5 rows x 130 columns]

# %%
wcss_reduced = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state=42)
    kmeans.fit(features_binary_df)
    wcss_reduced.append(kmeans.inertia_)

# %%
# Plot the results
plt.figure(figsize=(12, 8))
plt.plot(range(1,11), wcss_reduced, marker='o', linestyle='--')
plt.title('Elbow Method For Optimal Number of Clusters (Reduced Range)')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.grid(True)
plt.show()

# %%
# Define the weights for each feature as provided
# Assigning weights based on perceived luxury contribution
weights = {
    '24/7 Power Backup': 8,
    '24/7 Water Supply': 4,
    '24x7 Security': 7,
    'ATM': 4,
    'Aerobics Centre': 6,
    'Airy Rooms': 8,
    'Amphitheatre': 7,
    'Badminton Court': 7,
    'Banquet Hall': 8,
    'Bar/Chill-Out Lounge': 9,
    'Barbecue': 7,
    'Basketball Court': 7,
    'Billiards': 7,
    'Bowling Alley': 8,
    'Business Lounge': 9,
    'CCTV Camera Security': 8,
    'Cafeteria': 6,
    'Car Parking': 6,
    'Card Room': 6,
    'Centrally Air Conditioned': 9,
    'Changing Area': 6,
    "Children's Play Area": 7,
    'Cigar Lounge': 9,
    'Clinic': 5,
    'Club House': 9,
    'Concierge Service': 9,
    'Conference room': 8,
    'Creche/Day care': 7,
    'Cricket Pitch': 7,
    'Doctor on Call': 6,
    'Earthquake Resistant': 5,
    'Entrance Lobby': 7,
    'False Ceiling Lighting': 6,
    'Feng Shui / Vaastu Compliant': 5,
    'Fire Fighting Systems': 8,
    'Fitness Centre / GYM': 8,
    'Flower Garden': 7,
    'Food Court': 6,
    'Foosball': 5,
    'Football': 7,
    'Fountain': 7,
    'Gated Community': 7,
    'Golf Course': 10,
    'Grocery Shop': 6,
    'Gymnasium': 8,
    'High Ceiling Height': 8,
    'High Speed Elevators': 8,
    'Infinity Pool': 9,
    'Intercom Facility': 7,
    'Internal Street Lights': 6,
    'Internet/wi-fi connectivity': 7,
    'Jacuzzi': 9,
    'Jogging Track': 7,
    'Landscape Garden': 8,
    'Laundry': 6,
    'Lawn Tennis Court': 8,
    'Library': 8,
    'Lounge': 8,
    'Low Density Society': 7,
    'Maintenance Staff': 6,
    'Manicured Garden': 7,
    'Medical Centre': 5,
    'Milk Booth': 4,
    'Mini Theatre': 9,
    'Multipurpose Court': 7,
    'Multipurpose Hall': 7,
    'Natural Light': 8,
    'Natural Pond': 7,
    'Park': 8,
    'Party Lawn': 8,
    'Piped Gas': 7,
    'Pool Table': 7,
    'Power Back up Lift': 8,
    'Private Garden / Terrace': 9,
    'Property Staff': 7,
    'RO System': 7,
    'Rain Water Harvesting': 7,
    'Reading Lounge': 8,
    'Restaurant': 8,
    'Salon': 8,
    'Sauna': 9,
    'Security / Fire Alarm': 9,
    'Security Personnel': 9,
    'Separate entry for servant room': 8,
    'Sewage Treatment Plant': 6,
    'Shopping Centre': 7,
    'Skating Rink': 7,
    'Solar Lighting': 6,
    'Solar Water Heating': 7,
    'Spa': 9,
    'Spacious Interiors': 9,
    'Squash Court': 8,
    'Steam Room': 9,
    'Sun Deck': 8,
    'Swimming Pool': 8,
    'Temple': 5,
    'Theatre': 9,
    'Toddler Pool': 7,
    'Valet Parking': 9,
    'Video Door Security': 9,
    'Visitor Parking': 7,
    'Water Softener Plant': 7,
    'Water Storage': 7,
    'Water purifier': 7,
    'Yoga/Meditation Area': 7
}
# Calculate luxury score for each row
luxury_score = features_binary_df[list(weights.keys())].multiply(list(weights.values())).sum(axis=1)

# %%
df['luxury_score'] = luxury_score
df.head(1)
# Out:
#                   property_name property_type                 society  \
# 0  2 BHK Flat in Krishna Colony          flat  maa bhagwati residency
#
#      sector  price_in_lacs  price_per_sqft_inrs   area  \
# 0  sector 7           45.0               5000.0  900.0
#
#                      areaWithType super_builtup builtup  ... furnish_type  \
# 0  Carpet area: 900 (83.61 sq.m.)          None    None  ...          0.0
#
#                                             features  \
# 0  ['Feng Shui / Vaastu Compliant', 'Security / F...
#
#                                               rating servant_room study room  \
# 0  ['Environment4 out of 5', 'Safety4 out of 5', ...            0          0
#
#   pooja room  store_room others  \
# 0          0           0      0
#
#                                        features_list luxury_score
# 0  [Feng Shui / Vaastu Compliant, Security / Fire...         28.0
#
# [1 rows x 32 columns]

# %%
# cols to drop -> nearbyLocations,furnishDetails, features,features_list, additionalRoom
df.drop(columns=['nearbyLocations','furnishDetails','features','features_list','additionalRoom'],inplace=True)

# %%
df.sample(1)
# Out:
#                         property_name property_type                  society  \
# 964  3 BHK Flat in Sector 113 Gurgaon          flat  la vida by tata housing
#
#           sector  price_in_lacs  price_per_sqft_inrs     area  \
# 964  sector 113           300.0              14285.0  2100.11
#
#                                           areaWithType super_builtup builtup  \
# 964  Super Built up area 2691(250 sq.m.)Built Up ar...          2691    2460
#
#      ...   agePossession                                        description  \
# 964  ...  Relatively New  La vida by tata housing is one of the most pop...
#
#      furnish_type rating servant_room  study room pooja room store_room  \
# 964           2.0    NaN            1           0          0          0
#
#     others  luxury_score
# 964      0         174.0
#
# [1 rows x 27 columns]

# %%
df.to_csv(r'C:\Users\abc\Data Science and ML\CampusX\Project\self\project_1.csv',index=False)
